# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("special.csv")
df
# Out:
#     special_measures_key                                              title  \
# 0                      1       Ontario Declares Second Provincial Emergency
# 1                      2  Ontario Moving Additional Region to Modified S...
# 2                      3  Ontario Moves Public Health Unit Regions into ...
# 3                      4  Ontario Moving Regions to New Levels in COVID-...
# 4                      5  Ontario Moving Three Regions to New Levels in ...
# 5                      6  Ontario Moving Regions to New Levels with Stro...
# 6                      7         Ontario Expands COVID-19 Vaccine Locations
# 7                      8  Ontario Taking Further Action to Limit Spread ...
# 8                      9  Ontario Confirms First Cases of COVID-19 UK Va...
# 9                     10  Ontario Accelerates COVID-19 Vaccinations for ...
# 10                    11  Ontario Returning 27 Public Health Regions to ...
#
# ...

# %%
df = df.sort_values(by ='start_date',ascending=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df['special_measures_key'] = df.index + 1

# %%
df
# Out:
#     special_measures_key                                              title  \
# 0                      1  Ontario Moving Additional Region to Modified S...
# 1                      2  Ontario Moves Public Health Unit Regions into ...
# 2                      3  Ontario Moving Regions to New Levels in COVID-...
# 3                      4  Ontario Moving Three Regions to New Levels in ...
# 4                      5  Ontario Moving Regions to New Levels with Stro...
# 5                      6         Ontario Expands COVID-19 Vaccine Locations
# 6                      7  Ontario Taking Further Action to Limit Spread ...
# 7                      8  Ontario Confirms First Cases of COVID-19 UK Va...
# 8                      9  Ontario Accelerates COVID-19 Vaccinations for ...
# 9                     10       Ontario Declares Second Provincial Emergency
# 10                    11  Ontario Returning 27 Public Health Regions to ...
#
# ...

# %%
df.to_csv("s.csv",index=False)
